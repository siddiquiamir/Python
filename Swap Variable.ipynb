# %% [markdown]
# # Swap Variables

# %%
x = 2
y = 3

# %%
print(x)
# Out:
# 2

# %%
print(y)
# Out:
# 3

# %%
x= y

# %%
y= x

# %%
print(x)
# Out:
# 3

# %%
print(y)
# Out:
# 3

# %%
x = x+y
y= x-y
x = x-y

# %%
print(x)
# Out:
# 3

# %%
print(y)
# Out:
# 2

# %%
x = 2
y = 3

# %%
x,y = y,x

# %%
print(x)
# Out:
# 3

# %%
print(y)
# Out:
# 2
